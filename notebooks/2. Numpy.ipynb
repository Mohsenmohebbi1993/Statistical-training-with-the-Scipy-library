# %% [markdown]
# # 2. Numpy (Numerical Python)
# Array
# Matrix
# Array 2D and ND
# Type of Data
# Creat Array
# Indexing And Slicing
# Array 1D and ND
# Shape And Reshape
# Mathmatic
# Elementwise
# Aggragate
# Boolian
# Set
# Work on Array

# %%
import numpy as np
